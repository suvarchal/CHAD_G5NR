# %% [markdown]
# #  A GEOS-5 Nature Run case study

# %%
loadBundle('');
# Out:
# 3D [dev] 1.6.0-pre9-daily-experimental daily
#
# exec(u"loadBundle('http://weather.rsmas.miami.edu/repository/entry/get?entryid=8bc7c055-ca2c-4533-93cf-604db757b128');")
# Reached EOF Restarting Jython

# %% [markdown]
# ### Work the GUI, and capture the view any time with showImg(), showImgWithLegend(), showImgWithFullWindow(). Careful -- this is a screen capture, nothing must be in front of the IDV view window

# %%
showImgWithLegend()

# %% [markdown]
# ### How about an animation?

# %%
%showMovie

writeMovie("MyMovie.gif")

%Image MyMovie.gif

# %%
%%Latex
\overline{End}
# Out:
# $$\overline{End}$$
